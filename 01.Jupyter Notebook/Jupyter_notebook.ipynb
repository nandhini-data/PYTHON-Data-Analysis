# %% [markdown]
# # <center>Jupyter Notebook</center>

# %% [markdown]
# * [<span style='color:purple'>**Primary Coding Environment - Jupyter Notebook**](#Primary-Coding-Environment---Jupyter-Notebook)
#     * [<span style='color:purple'>Note 1](#Note-1:)

# %% [markdown]
# # <center>Primary Coding Environment - Jupyter Notebook</center>
#
# 1. Jupyter notebook are free to use.
# 2. It is the industry standard for conducting data analysis with python.
# 3. Google colab is an alternative of jupyter notebook and it is the cloud based environment as well.

# %% [markdown]
# ![jupyter.png](attachment:jupyter.png)

# %% [markdown]
# ### Note 1:
# <span style='color:purple'> 1. **Jupyter Notebook** are popular among analyst and data scientist,it allow you to create and document entire analytical workflow and render the output and visualization on screen.<br>
#     2. **Code cell** allow you to write and execute python code.<br>
#     3. use **comments** and **markdown** cells for documentation.
